# %% [markdown]
# # Data Gathering

# %%
import pandas as pd
import numpy as np

# %%
import json

# Enter your keys/secrets as strings in the following fields
credentials = {}  
credentials['CONSUMER_KEY'] = 'Kiy6NRGCfVjKbHJGS5S7cQWAC'  
credentials['CONSUMER_SECRET'] = 'jypnrUKv4rcNVgQ6HLgo0TNJHaNKIdd7KPvY2j6OfQXT3c0zap'  
credentials['ACCESS_TOKEN'] = '1493700385-ZJISpm8q1GzLNHj5Uy0Oom84mKdl8Mql66Qi30h'  
credentials['ACCESS_SECRET'] = 'HVDsTxtJJz0rSPp7VHnZ3u5uLoyzYN77bPRXzRZ96TEt3'

# Save the credentials object to file
with open("twitter_credentials.json", "w") as file:  
    json.dump(credentials, file)

# %%
# # Import the Twython class
# from twython import Twython  
# import json

# # Load credentials from json file
# with open("twitter_credentials.json", "r") as file:  
#     creds = json.load(file)

# # Instantiate an object
# python_tweets = Twython(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])

# %%
# from twython import TwythonStreamer  
# import csv

# # Filter out unwanted data
# def process_tweet(tweet):  
#     d = {}
#     d['hashtags'] = [hashtag['text'] for hashtag in tweet['entities']['hashtags']]
#     d['text'] = tweet['text']
#     d['user'] = tweet['user']['screen_name']
#     d['user_loc'] = tweet['user']['location']
#     return d


# # Create a class that inherits TwythonStreamer
# class MyStreamer(TwythonStreamer):     

#     # Received data
#     def on_success(self, data):

#         # Only collect tweets in English
#         if data['lang'] == 'en':
#             tweet_data = process_tweet(data)
#             self.save_to_csv(tweet_data)

#     # Problem with the API
#     def on_error(self, status_code, data):
#         print(status_code, data)
#         self.disconnect()

#     # Save each tweet to csv file
#     def save_to_csv(self, tweet):
#         with open(r'saved_tweets.csv', 'a') as file:
#             writer = csv.writer(file)
#             writer.writerow(list(tweet.values()))

# %%
# stream = MyStreamer(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'],  
#                     creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])
# # Start the stream
# stream.statuses.filter(track='power outage')

# %%
import tweepy as tw

auth = tw.OAuthHandler(credentials['CONSUMER_KEY'], credentials['CONSUMER_SECRET'])
auth.set_access_token(credentials['ACCESS_TOKEN'], credentials['ACCESS_SECRET'])

api = tw.API(auth)

# %%
search_words = 'power outage'
date_since = "2019-04-01"

# %%
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(20)

# %%
data = []
for tweet in tweets:
    content = {}
    content['tweets'] = tweet.text
    content['location'] = tweet.user.location
    content['date'] = tweet.created_at
    data.append(content)
    
df = pd.DataFrame(data)

# %%
df
# Out:
#                   date                      location  \
# 0  2019-04-15 00:41:08
# 1  2019-04-15 00:40:23
# 2  2019-04-15 00:40:13                 Knoxville, TN
# 3  2019-04-15 00:37:53
# 4  2019-04-15 00:37:53                        Athens
# 5  2019-04-15 00:36:26                      New York
# 6  2019-04-15 00:36:25                 United States
# 7  2019-04-15 00:35:13  Coastal Jersey...in the sand
# 8  2019-04-15 00:34:27                  Athens, Ohio
# 9  2019-04-15 00:33:41                Badstreet, USA
# 10 2019-04-15 00:31:46                         Osaka
# 11 2019-04-15 00:31:07                  Columbus, OH
# 12 2019-04-15 00:30:21            On Melancholy Hill
# 13 2019-04-15 00:29:21
# 14 2019-04-15 00:28:43           42nd Parallel North
# 15 2019-04-15 00:28:22                Portsmouth, VA
# 16 2019-04-15 00:28:11
# 17 2019-04-15 00:27:54              Pukalani, HI USA
# 18 2019-04-15 00:27:38                  Athens, Ohio
# 19 2019-04-15 00:26:49                 Greenbelt, MD
#
#                                                tweets
# 0   @CornBeltEnergy power outage in Downs, Il. 7:30pm
# 1              @MauiElectric power outage upcountry??
# 2   When @davidking08 breaks the power outage news...
# 3   4-14-2019 @ 8:35 pm \n\nPower outage on Highwa...
# 4   RT @TheAthensNEWS: Two trees were downed on Co...
# 5   RT @bebarce: Hi all,\n\nJust putting it out th...
# 6   @KnoxKUB &amp; @MayorRogero your power infrast...
# 7   We had a power outage....it's not working.... ...
# 8   RT @TheAthensNEWS: Two trees were downed on Co...
# 9   Power outage, day one: \n\nChild is bored and ...
# 10  Disaster-related information in Facebook, ther...
# 11  RT @TheAthensNEWS: Two trees were downed on Co...
# 12  On boy, lightning. I can't wait for the inevit...
# 13  RT @cityofoakridge: As a reminder, please do n...
# 14  @von_lex Yes, but we’re not Hydro One, small c...
# 15  RT @dog_feelings: the human likes to cover my ...
# 16  RT @TheAthensNEWS: Two trees were downed on Co...
# 17  Whoops... high winds = power outage. Again. Bb...
# 18  Two trees were downed on College Green in Athe...
# 19  It’s also possible I get a power-outage mid-Tw...

# %%
# saved dataframe to data directory
df.to_csv('./data/tweets.csv', index=False)

# %%
for tweet in tweets:
    print(tweet.text)
    print(tweet.user.location)
    print(tweet.created_at)
# Out:
# 4-14-2019 @ 8:35 pm
#
# Power outage on Highway 589, 437, 172, Cindas Creek, &amp; Patoker area.
#
# Servicemen are notified… https://t.co/vgfvd10qiP
#
# 2019-04-15 00:37:53
# RT @TheAthensNEWS: Two trees were downed on College Green in Athens during the storm this evening. Photos by Zach Reizes. As of 8:25 this e…
# Athens
# 2019-04-15 00:37:53
# RT @bebarce: Hi all,
#
# Just putting it out there if you are a:
# reviewer/interviewer
# twitch or youtube streamer of TRPGs
#
# and are interested…
# New York
# 2019-04-15 00:36:26
# @KnoxKUB &amp; @MayorRogero your power infrastructure is about as reliable as the systems in Venezuela. Third outage in… https://t.co/F6lPdyRk2c
# United States
# 2019-04-15 00:36:25
# We had a power outage....it's not working.... AAAAAAAH! #GameofThrones https://t.co/k1tCSH4ZlI
# Coastal Jersey...in the sand
# 2019-04-15 00:35:13
# RT @TheAthensNEWS: Two trees were downed on College Green in Athens during the storm this evening. Photos by Zach Reizes. As of 8:25 this e…
# Athens, Ohio
# 2019-04-15 00:34:27
# Power outage, day one:
#
# Child is bored and confused.
#
# His young son is as well.
#
# Cats growing skeptical of supposed human dominance.
# Badstreet, USA
# 2019-04-15 00:33:41
# Disaster-related information in Facebook, there are displays of power outage plan. https://t.co/lufwqsp9iC #jishin #followme
# Osaka
# 2019-04-15 00:31:46
# RT @TheAthensNEWS: Two trees were downed on College Green in Athens during the storm this evening. Photos by Zach Reizes. As of 8:25 this e…
# Columbus, OH
# 2019-04-15 00:31:07
# On boy, lightning. I can't wait for the inevitable power outage.
# On Melancholy Hill
# 2019-04-15 00:30:21
# RT @cityofoakridge: As a reminder, please do not dial 911 due to a power outage unless you are injured or have an emergency. (4/5) https://…
#
# 2019-04-15 00:29:21
# @von_lex Yes, but we’re not Hydro One, small company called Essex Power Lines. Checked their outage page too. Nada :-/
# 42nd Parallel North
# 2019-04-15 00:28:43
# RT @dog_feelings: the human likes to cover my eyes with my ears. and pretend there’s been a power outage. i go along with this. because it…
# Portsmouth, VA
# 2019-04-15 00:28:22
# RT @TheAthensNEWS: Two trees were downed on College Green in Athens during the storm this evening. Photos by Zach Reizes. As of 8:25 this e…
#
# 2019-04-15 00:28:11
# Whoops... high winds = power outage. Again. Bbl : )
# Pukalani, HI USA
# 2019-04-15 00:27:54
# Two trees were downed on College Green in Athens during the storm this evening. Photos by Zach Reizes. As of 8:25 t… https://t.co/8mfPT4Q2nE
# Athens, Ohio
# 2019-04-15 00:27:38
# It’s also possible I get a power-outage mid-Tweet and you’ll be lucky not to see how hard I’m decompensating without my GOT.
# Greenbelt, MD
# 2019-04-15 00:26:49
# Great timing for a power outage on the block! 👎🏼 #GameOfThrones
# Memphis, TN
# 2019-04-15 00:26:31
# Not even a power outage will stop me from watching, HBO NOW bitches.
# #GameofThrones
# In the wilds of Texas
# 2019-04-15 00:25:53
# Hope it isn't some power outage next.
# Toronto, Ontario
# 2019-04-15 00:24:20

# %%
# for status in tw.Cursor(api.home_timeline).items(20):
#     # Process a single status
#     print(status.text)
#     print(status.geo)
#     print(type(status.created_at))
#     print(status.coordinates)

# %%
api.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '1493700385-ZJISpm8q1GzLNHj5Uy0Oom84mKdl8Mql66Qi30h'},
#  'resources': {'lists': {'/lists/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1555258583},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1555258583},
#    '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1555258583},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1555258583},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1555258583}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 179,
#     'reset': 1555258583}},
#   'mutes': {'/mutes/users/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/mutes/users/ids': {'limit': 15, 'remaining': 15, 'reset': 1555258583}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1555258583}},
#   'friendships': {'/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1555258583},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1555258583}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1555258583}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583}},
#   'blocks': {'/blocks/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/blocks/ids': {'limit': 15, 'remaining': 15, 'reset': 1555258583}},
#   'geo': {'/geo/similar_places': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/geo/id/:place_id': {'limit': 75, 'remaining': 75, 'reset': 1555258583},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1555258583}},
#   'users': {'/users/report_spam': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1555258583},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1555258583},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1555258583},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1555258583},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1555258583},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1555258583}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1555258583}},
#   'collections': {'/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1555258583},
#    '/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1555258583},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1555258583}},
#   'statuses': {'/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1555258583},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1555258583},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1555258583},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1555258583},
#    '/statuses/friends': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1555258583},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1555258583},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1555258583},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1555258583}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583}},
#   'webhooks': {'/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/webhooks': {'limit': 15, 'remaining': 15, 'reset': 1555258583}},
#   'contacts': {'/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1555258583},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1555258583},
#    '/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1555258583},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1555258583},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1555258583}},
#   'labs': {'/labs/:version/users': {'limit': 3000,
#     'remaining': 3000,
#     'reset': 1555258583},
#    '/labs/:version/tweets': {'limit': 3000,
#     'remaining': 3000,
#     'reset': 1555258583}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1555258583}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583}},
#   'moments': {'/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1555258583},
#    '/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1555258583}},
#   'help': {'/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/help/configuration': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1555258583}},
#   'feedback': {'/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583},
#    '/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1555258583}},
#   'business_experience': {'/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583}},
#   'graphql&POST': {'/graphql&POST': {'limit': 2500,
#     'remaining': 2500,
#     'reset': 1555258583}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1555258583},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1555258583}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1555258583}},
#   'drafts': {'/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583}},
#   'direct_messages': {'/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1555258583},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1555258583},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1555258583},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1555258583},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1555258583},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1555258583},
#    '/direct_messages': {'limit': 300, 'remaining': 300, 'reset': 1555258583},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1555258583},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1555258583},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1555258583},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1555258583}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583}},
#   'account_activity': {'/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1555258583},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1555258583},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1555258583},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1555258583},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583}},
#   'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1555258583},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1555258583}},
#   'safety': {'/safety/detection_feedback': {'limit': 450000,
#     'remaining': 450000,
#     'reset': 1555258583}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1555258583}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583}},
#   'tweets': {'/tweets/stream/filter/rules': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/tweets/stream/filter/:instance_name': {'limit': 50,
#     'remaining': 50,
#     'reset': 1555258583},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1555258583},
#    '/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1555258583},
#    '/tweets/stream/filter/rules/:instance_name/validation&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/tweets/stream/filter/rules/:instance_name&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/tweets/stream/filter/rules/:instance_name&DELETE': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583},
#    '/tweets/stream/filter/rules/:instance_name/:rule_id': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583},
#    '/saved_searches/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1555258583}},
#   'oauth': {'/oauth/invalidate_token': {'limit': 450,
#     'remaining': 450,
#     'reset': 1555258583}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583}},
#   'trends': {'/trends/closest': {'limit': 75,
#     'remaining': 75,
#     'reset': 1555258583},
#    '/trends/available': {'limit': 75, 'remaining': 75, 'reset': 1555258583},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1555258583}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1555258583}}}}
